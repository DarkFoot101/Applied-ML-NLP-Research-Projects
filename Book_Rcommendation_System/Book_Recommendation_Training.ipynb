# %%
import numpy as np 
import pandas as pd

# %%
books = pd.read_csv("Books.csv")
users = pd.read_csv("Users.csv")
ratings = pd.read_csv("Ratings.csv")
# Out:
# C:\Users\priya\AppData\Local\Temp\ipykernel_14004\2906776592.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books = pd.read_csv("Books.csv")

# %%
books.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...

# %%
users.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
print(books.shape)
print(ratings.shape)
print(users.shape)
# Out:
# (271360, 8)
# (1149780, 3)
# (278858, 3)

# %%
books.isnull().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            2
# Year-Of-Publication    0
# Publisher              2
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            3
# dtype: int64

# %%
users.isnull().sum()
# Out:
# User-ID          0
# Location         0
# Age         110762
# dtype: int64

# %%
ratings.isnull().sum()
# Out:
# User-ID        0
# ISBN           0
# Book-Rating    0
# dtype: int64

# %%
books.duplicated().sum()
# Out:
# np.int64(0)

# %%
ratings.duplicated().sum()
# Out:
# np.int64(0)

# %%
users.duplicated().sum()
# Out:
# np.int64(0)

# %%
# To first create a popularity based system
ratings_with_name = ratings.merge(books, on = "ISBN")

# %%
ratings_with_name
# Out:
#          User-ID        ISBN  Book-Rating  \
# 0         276725  034545104X            0
# 1         276726  0155061224            5
# 2         276727  0446520802            0
# 3         276729  052165615X            3
# 4         276729  0521795028            6
# ...          ...         ...          ...
# 1031131   276704  0876044011            0
# 1031132   276704  1563526298            9
# 1031133   276706  0679447156            0
# 1031134   276709  0515107662           10
# 1031135   276721  0590442449           10
#
#                                                 Book-Title        Book-Author  \
# 0                                     Flesh Tones: A Novel         M. J. Rose
# 1                                         Rites of Passage         Judith Rae
# 2                                             The Notebook    Nicholas Sparks
# 3                                           Help!: Level 1      Philip Prowse
# 4        The Amsterdam Connection : Level 4 (Cambridge ...        Sue Leather
# ...                                                    ...                ...
# 1031131  Edgar Cayce on the Akashic Records: The Book o...  Kevin J. Todeschi
# 1031132  Get Clark Smart : The Ultimate Guide for the S...       Clark Howard
# 1031133  Eight Weeks to Optimum Health: A Proven Progra...        Andrew Weil
# 1031134   The Sherbrooke Bride (Bride Trilogy (Paperback))  Catherine Coulter
# 1031135                                  Fourth Grade Rats     Jerry Spinelli
#
#         Year-Of-Publication  \
# 0                      2002
# 1                      2001
# 2                      1996
# 3                      1999
# 4                      2001
# ...                     ...
# 1031131                1998
# 1031132                2000
# 1031133                1997
# 1031134                1996
# 1031135                1996
#
#                                                  Publisher  \
# 0                                         Ballantine Books
# 1                                                   Heinle
# 2                                             Warner Books
# 3                               Cambridge University Press
# 4                               Cambridge University Press
# ...                                                    ...
# 1031131  A.R.E. Press (Association of Research &amp; Enlig
# 1031132                                   Longstreet Press
# 1031133                                    Alfred A. Knopf
# 1031134                                         Jove Books
# 1031135                                         Scholastic
#
#                                                Image-URL-S  \
# 0        http://images.amazon.com/images/P/034545104X.0...
# 1        http://images.amazon.com/images/P/0155061224.0...
# 2        http://images.amazon.com/images/P/0446520802.0...
# 3        http://images.amazon.com/images/P/052165615X.0...
# 4        http://images.amazon.com/images/P/0521795028.0...
# ...                                                    ...
# 1031131  http://images.amazon.com/images/P/0876044011.0...
# 1031132  http://images.amazon.com/images/P/1563526298.0...
# 1031133  http://images.amazon.com/images/P/0679447156.0...
# 1031134  http://images.amazon.com/images/P/0515107662.0...
# 1031135  http://images.amazon.com/images/P/0590442449.0...
#
#                                                Image-URL-M  \
# 0        http://images.amazon.com/images/P/034545104X.0...
# 1        http://images.amazon.com/images/P/0155061224.0...
# 2        http://images.amazon.com/images/P/0446520802.0...
# 3        http://images.amazon.com/images/P/052165615X.0...
# 4        http://images.amazon.com/images/P/0521795028.0...
# ...                                                    ...
# 1031131  http://images.amazon.com/images/P/0876044011.0...
# 1031132  http://images.amazon.com/images/P/1563526298.0...
# 1031133  http://images.amazon.com/images/P/0679447156.0...
# 1031134  http://images.amazon.com/images/P/0515107662.0...
# 1031135  http://images.amazon.com/images/P/0590442449.0...
#
#                                                Image-URL-L
# 0        http://images.amazon.com/images/P/034545104X.0...
# 1        http://images.amazon.com/images/P/0155061224.0...
# 2        http://images.amazon.com/images/P/0446520802.0...
# 3        http://images.amazon.com/images/P/052165615X.0...
# 4        http://images.amazon.com/images/P/0521795028.0...
# ...                                                    ...
# 1031131  http://images.amazon.com/images/P/0876044011.0...
# 1031132  http://images.amazon.com/images/P/1563526298.0...
# 1031133  http://images.amazon.com/images/P/0679447156.0...
# 1031134  http://images.amazon.com/images/P/0515107662.0...
# 1031135  http://images.amazon.com/images/P/0590442449.0...
#
# [1031136 rows x 10 columns]

# %%
num_rating_df = ratings_with_name.groupby("Book-Title").count()['Book-Rating'].reset_index()
num_rating_df.rename(columns = {'Book-Rating' : 'num_ratings'}, inplace = True)
num_rating_df
# Out:
#                                                Book-Title  num_ratings
# 0        A Light in the Storm: The Civil War Diary of ...            4
# 1                                   Always Have Popsicles            1
# 2                    Apple Magic (The Collector's series)            1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...            1
# 4        Beyond IBM: Leadership Marketing and Finance ...            1
# ...                                                   ...          ...
# 241066                                      Ã?Â?lpiraten.            2
# 241067                     Ã?Â?rger mit Produkt X. Roman.            4
# 241068                                Ã?Â?sterlich leben.            1
# 241069                              Ã?Â?stlich der Berge.            3
# 241070                                  Ã?Â?thique en toc            2
#
# [241071 rows x 2 columns]

# %%
avg_rating_df = (
    ratings_with_name.groupby("Book-Title")["Book-Rating"]
    .mean()
    .reset_index()
)
avg_rating_df.rename(columns = {"Book-Rating" : "avg_ratings"}, inplace = True)
avg_rating_df
# Out:
#                                                Book-Title  avg_ratings
# 0        A Light in the Storm: The Civil War Diary of ...     2.250000
# 1                                   Always Have Popsicles     0.000000
# 2                    Apple Magic (The Collector's series)     0.000000
# 3        Ask Lily (Young Women of Faith: Lily Series, ...     8.000000
# 4        Beyond IBM: Leadership Marketing and Finance ...     0.000000
# ...                                                   ...          ...
# 241066                                      Ã?Â?lpiraten.     0.000000
# 241067                     Ã?Â?rger mit Produkt X. Roman.     5.250000
# 241068                                Ã?Â?sterlich leben.     7.000000
# 241069                              Ã?Â?stlich der Berge.     2.666667
# 241070                                  Ã?Â?thique en toc     4.000000
#
# [241071 rows x 2 columns]

# %%
popularity_df = num_rating_df.merge(avg_rating_df, on = "Book-Title")
popularity_df
# Out:
#                                                Book-Title  num_ratings  \
# 0        A Light in the Storm: The Civil War Diary of ...            4
# 1                                   Always Have Popsicles            1
# 2                    Apple Magic (The Collector's series)            1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...            1
# 4        Beyond IBM: Leadership Marketing and Finance ...            1
# ...                                                   ...          ...
# 241066                                      Ã?Â?lpiraten.            2
# 241067                     Ã?Â?rger mit Produkt X. Roman.            4
# 241068                                Ã?Â?sterlich leben.            1
# 241069                              Ã?Â?stlich der Berge.            3
# 241070                                  Ã?Â?thique en toc            2
#
#         avg_ratings
# 0          2.250000
# 1          0.000000
# 2          0.000000
# 3          8.000000
# 4          0.000000
# ...             ...
# 241066     0.000000
# 241067     5.250000
# 241068     7.000000
# 241069     2.666667
# 241070     4.000000
#
# [241071 rows x 3 columns]

# %%
popularity_df = popularity_df[popularity_df["num_ratings"] >= 100].sort_values('avg_ratings', ascending= False).head(80)

# %%
popularity_df = popularity_df.merge(books, on = 'Book-Title').drop_duplicates('Book-Title')[['Book-Title', 'Book-Author', 'Image-URL-M', 'num_ratings', 'avg_ratings', 'Year-Of-Publication']]

# %%
popularity_df.shape
# Out:
# (80, 6)

# %%
## now use the collabartive filter based approach
ratings_with_name
# Out:
#          User-ID        ISBN  Book-Rating  \
# 0         276725  034545104X            0
# 1         276726  0155061224            5
# 2         276727  0446520802            0
# 3         276729  052165615X            3
# 4         276729  0521795028            6
# ...          ...         ...          ...
# 1031131   276704  0876044011            0
# 1031132   276704  1563526298            9
# 1031133   276706  0679447156            0
# 1031134   276709  0515107662           10
# 1031135   276721  0590442449           10
#
#                                                 Book-Title        Book-Author  \
# 0                                     Flesh Tones: A Novel         M. J. Rose
# 1                                         Rites of Passage         Judith Rae
# 2                                             The Notebook    Nicholas Sparks
# 3                                           Help!: Level 1      Philip Prowse
# 4        The Amsterdam Connection : Level 4 (Cambridge ...        Sue Leather
# ...                                                    ...                ...
# 1031131  Edgar Cayce on the Akashic Records: The Book o...  Kevin J. Todeschi
# 1031132  Get Clark Smart : The Ultimate Guide for the S...       Clark Howard
# 1031133  Eight Weeks to Optimum Health: A Proven Progra...        Andrew Weil
# 1031134   The Sherbrooke Bride (Bride Trilogy (Paperback))  Catherine Coulter
# 1031135                                  Fourth Grade Rats     Jerry Spinelli
#
#         Year-Of-Publication  \
# 0                      2002
# 1                      2001
# 2                      1996
# 3                      1999
# 4                      2001
# ...                     ...
# 1031131                1998
# 1031132                2000
# 1031133                1997
# 1031134                1996
# 1031135                1996
#
#                                                  Publisher  \
# 0                                         Ballantine Books
# 1                                                   Heinle
# 2                                             Warner Books
# 3                               Cambridge University Press
# 4                               Cambridge University Press
# ...                                                    ...
# 1031131  A.R.E. Press (Association of Research &amp; Enlig
# 1031132                                   Longstreet Press
# 1031133                                    Alfred A. Knopf
# 1031134                                         Jove Books
# 1031135                                         Scholastic
#
#                                                Image-URL-S  \
# 0        http://images.amazon.com/images/P/034545104X.0...
# 1        http://images.amazon.com/images/P/0155061224.0...
# 2        http://images.amazon.com/images/P/0446520802.0...
# 3        http://images.amazon.com/images/P/052165615X.0...
# 4        http://images.amazon.com/images/P/0521795028.0...
# ...                                                    ...
# 1031131  http://images.amazon.com/images/P/0876044011.0...
# 1031132  http://images.amazon.com/images/P/1563526298.0...
# 1031133  http://images.amazon.com/images/P/0679447156.0...
# 1031134  http://images.amazon.com/images/P/0515107662.0...
# 1031135  http://images.amazon.com/images/P/0590442449.0...
#
#                                                Image-URL-M  \
# 0        http://images.amazon.com/images/P/034545104X.0...
# 1        http://images.amazon.com/images/P/0155061224.0...
# 2        http://images.amazon.com/images/P/0446520802.0...
# 3        http://images.amazon.com/images/P/052165615X.0...
# 4        http://images.amazon.com/images/P/0521795028.0...
# ...                                                    ...
# 1031131  http://images.amazon.com/images/P/0876044011.0...
# 1031132  http://images.amazon.com/images/P/1563526298.0...
# 1031133  http://images.amazon.com/images/P/0679447156.0...
# 1031134  http://images.amazon.com/images/P/0515107662.0...
# 1031135  http://images.amazon.com/images/P/0590442449.0...
#
#                                                Image-URL-L
# 0        http://images.amazon.com/images/P/034545104X.0...
# 1        http://images.amazon.com/images/P/0155061224.0...
# 2        http://images.amazon.com/images/P/0446520802.0...
# 3        http://images.amazon.com/images/P/052165615X.0...
# 4        http://images.amazon.com/images/P/0521795028.0...
# ...                                                    ...
# 1031131  http://images.amazon.com/images/P/0876044011.0...
# 1031132  http://images.amazon.com/images/P/1563526298.0...
# 1031133  http://images.amazon.com/images/P/0679447156.0...
# 1031134  http://images.amazon.com/images/P/0515107662.0...
# 1031135  http://images.amazon.com/images/P/0590442449.0...
#
# [1031136 rows x 10 columns]

# %%
x = ratings_with_name.groupby('User-ID').count()['Book-Rating'] > 100
read_users = x[x].index

# %%
filtered_rating = ratings_with_name[ratings_with_name['User-ID'].isin(read_users)]

# %%
y = filtered_rating.groupby('Book-Title').count()['Book-Rating'] >= 10
famous_books = y[y].index

# %%
final_ratings = filtered_rating[filtered_rating['Book-Title'].isin(famous_books)]

# %%
final_ratings.drop_duplicates()
# Out:
#          User-ID        ISBN  Book-Rating  \
# 1150      277427  002542730X           10
# 1154      277427  0060002050            0
# 1157      277427  0060177721            0
# 1158      277427  0060192704            0
# 1159      277427  0060542128            7
# ...          ...         ...          ...
# 1030985   276680  1573222038           10
# 1030986   276680  1573222267            0
# 1030987   276680  1573229083            7
# 1030988   276680  1573229865            0
# 1030995   276680  1931561648            9
#
#                                                 Book-Title  \
# 1150     Politically Correct Bedtime Stories: Modern Ta...
# 1154                     On a Wicked Dawn (Cynster Novels)
# 1157                                          Finding Moon
# 1158     Beauty Fades, Dumb Is Forever: The Making of a...
# 1159                                 When the Storm Breaks
# ...                                                    ...
# 1030985                                        Fingersmith
# 1030986                                          Blue Shoe
# 1030987                                    My Dream of You
# 1030988                                The Dream of Scipio
# 1030995  The Time Traveler's Wife (Today Show Book Club...
#
#                 Book-Author Year-Of-Publication                  Publisher  \
# 1150      James Finn Garner                1994  John Wiley &amp; Sons Inc
# 1154      Stephanie Laurens                2002                 Avon Books
# 1157         Tony Hillerman                1995              Harpercollins
# 1158         Judy Sheindlin                1999         Cliff Street Books
# 1159         Heather Lowell                2003                HarperTorch
# ...                     ...                 ...                        ...
# 1030985        Sarah Waters                2002        Riverhead Hardcover
# 1030986         Anne Lamott                2002            Riverhead Books
# 1030987     Nuala O'Faolain                2002            Riverhead Books
# 1030988          Iain Pears                2003            Riverhead Books
# 1030995  Audrey Niffenegger                2003    MacAdam/Cage Publishing
#
#                                                Image-URL-S  \
# 1150     http://images.amazon.com/images/P/002542730X.0...
# 1154     http://images.amazon.com/images/P/0060002050.0...
# 1157     http://images.amazon.com/images/P/0060177721.0...
# 1158     http://images.amazon.com/images/P/0060192704.0...
# 1159     http://images.amazon.com/images/P/0060542128.0...
# ...                                                    ...
# 1030985  http://images.amazon.com/images/P/1573222038.0...
# 1030986  http://images.amazon.com/images/P/1573222267.0...
# 1030987  http://images.amazon.com/images/P/1573229083.0...
# 1030988  http://images.amazon.com/images/P/1573229865.0...
# 1030995  http://images.amazon.com/images/P/1931561648.0...
#
#                                                Image-URL-M  \
# 1150     http://images.amazon.com/images/P/002542730X.0...
# 1154     http://images.amazon.com/images/P/0060002050.0...
# 1157     http://images.amazon.com/images/P/0060177721.0...
# 1158     http://images.amazon.com/images/P/0060192704.0...
# 1159     http://images.amazon.com/images/P/0060542128.0...
# ...                                                    ...
# 1030985  http://images.amazon.com/images/P/1573222038.0...
# 1030986  http://images.amazon.com/images/P/1573222267.0...
# 1030987  http://images.amazon.com/images/P/1573229083.0...
# 1030988  http://images.amazon.com/images/P/1573229865.0...
# 1030995  http://images.amazon.com/images/P/1931561648.0...
#
#                                                Image-URL-L
# 1150     http://images.amazon.com/images/P/002542730X.0...
# 1154     http://images.amazon.com/images/P/0060002050.0...
# 1157     http://images.amazon.com/images/P/0060177721.0...
# 1158     http://images.amazon.com/images/P/0060192704.0...
# 1159     http://images.amazon.com/images/P/0060542128.0...
# ...                                                    ...
# 1030985  http://images.amazon.com/images/P/1573222038.0...
# 1030986  http://images.amazon.com/images/P/1573222267.0...
# 1030987  http://images.amazon.com/images/P/1573229083.0...
# 1030988  http://images.amazon.com/images/P/1573229865.0...
# 1030995  http://images.amazon.com/images/P/1931561648.0...
#
# [263876 rows x 10 columns]

# %%
pt = final_ratings.pivot_table(index = 'Book-Title', columns= 'User-ID', values='Book-Rating')

# %%
pt
# Out:
# User-ID                                             254     507     882     \
# Book-Title
#  Q-Space (Star Trek The Next Generation, Book 47)      NaN     NaN     NaN
# 'Salem's Lot                                           NaN     NaN     NaN
# 01-01-00: The Novel of the Millennium                  NaN     NaN     NaN
# 10 Lb. Penalty                                         NaN     NaN     NaN
# 1001 Ways to Be Romantic                               NaN     NaN     NaN
# ...                                                    ...     ...     ...
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
# \Surely You're Joking, Mr. Feynman!\": Adventur...     NaN     NaN     NaN
# e                                                      NaN     NaN     NaN
# one hundred years of solitude                          NaN     NaN     NaN
# stardust                                               0.0     NaN     NaN
#
# User-ID                                             1424    1435    1733    \
# Book-Title
#  Q-Space (Star Trek The Next Generation, Book 47)      NaN     NaN     NaN
# 'Salem's Lot                                           NaN     NaN     NaN
# 01-01-00: The Novel of the Millennium                  NaN     NaN     NaN
# 10 Lb. Penalty                                         NaN     NaN     NaN
# 1001 Ways to Be Romantic                               NaN     NaN     NaN
# ...                                                    ...     ...     ...
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
# \Surely You're Joking, Mr. Feynman!\": Adventur...     NaN     NaN     NaN
# e                                                      NaN     NaN     NaN
# one hundred years of solitude                          NaN     NaN     NaN
# stardust                                               NaN     NaN     NaN
#
# User-ID                                             1903    2033    2110    \
# Book-Title
#  Q-Space (Star Trek The Next Generation, Book 47)      NaN     NaN     NaN
# 'Salem's Lot                                           NaN     NaN     NaN
# 01-01-00: The Novel of the Millennium                  NaN     NaN     NaN
# 10 Lb. Penalty                                         NaN     NaN     NaN
# 1001 Ways to Be Romantic                               NaN     NaN     NaN
# ...                                                    ...     ...     ...
# \O\" Is for Outlaw"                                    NaN     0.0     NaN
# \Surely You're Joking, Mr. Feynman!\": Adventur...     NaN     NaN     NaN
# e                                                      NaN     NaN     NaN
# one hundred years of solitude                          NaN     NaN     NaN
# stardust                                               NaN     NaN     NaN
#
# User-ID                                             2276    ...  275020  \
# Book-Title                                                  ...
#  Q-Space (Star Trek The Next Generation, Book 47)      NaN  ...     NaN
# 'Salem's Lot                                           NaN  ...     NaN
# 01-01-00: The Novel of the Millennium                  NaN  ...     NaN
# 10 Lb. Penalty                                         NaN  ...     NaN
# 1001 Ways to Be Romantic                               NaN  ...     NaN
# ...                                                    ...  ...     ...
# \O\" Is for Outlaw"                                    NaN  ...     NaN
# \Surely You're Joking, Mr. Feynman!\": Adventur...     NaN  ...     NaN
# e                                                      NaN  ...     NaN
# one hundred years of solitude                          NaN  ...     NaN
# stardust                                               NaN  ...     NaN
#
# User-ID                                             275970  276463  276680  \
# Book-Title
#  Q-Space (Star Trek The Next Generation, Book 47)      NaN     NaN     NaN
# 'Salem's Lot                                           NaN     NaN     NaN
# 01-01-00: The Novel of the Millennium                  NaN     NaN     NaN
# 10 Lb. Penalty                                         NaN     NaN     NaN
# 1001 Ways to Be Romantic                               NaN     NaN     NaN
# ...                                                    ...     ...     ...
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
# \Surely You're Joking, Mr. Feynman!\": Adventur...     NaN     NaN     NaN
# e                                                      NaN     NaN     NaN
# one hundred years of solitude                          NaN     NaN     NaN
# stardust                                               NaN     NaN     NaN
#
# User-ID                                             277427  277478  277639  \
# Book-Title
#  Q-Space (Star Trek The Next Generation, Book 47)      NaN     NaN     NaN
# 'Salem's Lot                                           NaN     NaN     NaN
# 01-01-00: The Novel of the Millennium                  NaN     NaN     NaN
# 10 Lb. Penalty                                         NaN     NaN     NaN
# 1001 Ways to Be Romantic                               NaN     NaN     NaN
# ...                                                    ...     ...     ...
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
# \Surely You're Joking, Mr. Feynman!\": Adventur...     NaN     NaN     NaN
# e                                                      NaN     NaN     NaN
# one hundred years of solitude                          NaN     NaN     NaN
# stardust                                               NaN     NaN     NaN
#
# User-ID                                             278137  278188  278418
# Book-Title
#  Q-Space (Star Trek The Next Generation, Book 47)      NaN     NaN     NaN
# 'Salem's Lot                                           NaN     NaN     NaN
# 01-01-00: The Novel of the Millennium                  NaN     NaN     NaN
# 10 Lb. Penalty                                         NaN     NaN     NaN
# 1001 Ways to Be Romantic                               NaN     NaN     NaN
# ...                                                    ...     ...     ...
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
# \Surely You're Joking, Mr. Feynman!\": Adventur...     NaN     NaN     NaN
# e                                                      NaN     NaN     NaN
# one hundred years of solitude                          NaN     NaN     NaN
# stardust                                               NaN     NaN     NaN
#
# [9934 rows x 1645 columns]

# %%
pt.fillna(0 , inplace = True)

# %%
pt
# Out:
# User-ID                                             254     507     882     \
# Book-Title
#  Q-Space (Star Trek The Next Generation, Book 47)      0.0     0.0     0.0
# 'Salem's Lot                                           0.0     0.0     0.0
# 01-01-00: The Novel of the Millennium                  0.0     0.0     0.0
# 10 Lb. Penalty                                         0.0     0.0     0.0
# 1001 Ways to Be Romantic                               0.0     0.0     0.0
# ...                                                    ...     ...     ...
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
# \Surely You're Joking, Mr. Feynman!\": Adventur...     0.0     0.0     0.0
# e                                                      0.0     0.0     0.0
# one hundred years of solitude                          0.0     0.0     0.0
# stardust                                               0.0     0.0     0.0
#
# User-ID                                             1424    1435    1733    \
# Book-Title
#  Q-Space (Star Trek The Next Generation, Book 47)      0.0     0.0     0.0
# 'Salem's Lot                                           0.0     0.0     0.0
# 01-01-00: The Novel of the Millennium                  0.0     0.0     0.0
# 10 Lb. Penalty                                         0.0     0.0     0.0
# 1001 Ways to Be Romantic                               0.0     0.0     0.0
# ...                                                    ...     ...     ...
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
# \Surely You're Joking, Mr. Feynman!\": Adventur...     0.0     0.0     0.0
# e                                                      0.0     0.0     0.0
# one hundred years of solitude                          0.0     0.0     0.0
# stardust                                               0.0     0.0     0.0
#
# User-ID                                             1903    2033    2110    \
# Book-Title
#  Q-Space (Star Trek The Next Generation, Book 47)      0.0     0.0     0.0
# 'Salem's Lot                                           0.0     0.0     0.0
# 01-01-00: The Novel of the Millennium                  0.0     0.0     0.0
# 10 Lb. Penalty                                         0.0     0.0     0.0
# 1001 Ways to Be Romantic                               0.0     0.0     0.0
# ...                                                    ...     ...     ...
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
# \Surely You're Joking, Mr. Feynman!\": Adventur...     0.0     0.0     0.0
# e                                                      0.0     0.0     0.0
# one hundred years of solitude                          0.0     0.0     0.0
# stardust                                               0.0     0.0     0.0
#
# User-ID                                             2276    ...  275020  \
# Book-Title                                                  ...
#  Q-Space (Star Trek The Next Generation, Book 47)      0.0  ...     0.0
# 'Salem's Lot                                           0.0  ...     0.0
# 01-01-00: The Novel of the Millennium                  0.0  ...     0.0
# 10 Lb. Penalty                                         0.0  ...     0.0
# 1001 Ways to Be Romantic                               0.0  ...     0.0
# ...                                                    ...  ...     ...
# \O\" Is for Outlaw"                                    0.0  ...     0.0
# \Surely You're Joking, Mr. Feynman!\": Adventur...     0.0  ...     0.0
# e                                                      0.0  ...     0.0
# one hundred years of solitude                          0.0  ...     0.0
# stardust                                               0.0  ...     0.0
#
# User-ID                                             275970  276463  276680  \
# Book-Title
#  Q-Space (Star Trek The Next Generation, Book 47)      0.0     0.0     0.0
# 'Salem's Lot                                           0.0     0.0     0.0
# 01-01-00: The Novel of the Millennium                  0.0     0.0     0.0
# 10 Lb. Penalty                                         0.0     0.0     0.0
# 1001 Ways to Be Romantic                               0.0     0.0     0.0
# ...                                                    ...     ...     ...
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
# \Surely You're Joking, Mr. Feynman!\": Adventur...     0.0     0.0     0.0
# e                                                      0.0     0.0     0.0
# one hundred years of solitude                          0.0     0.0     0.0
# stardust                                               0.0     0.0     0.0
#
# User-ID                                             277427  277478  277639  \
# Book-Title
#  Q-Space (Star Trek The Next Generation, Book 47)      0.0     0.0     0.0
# 'Salem's Lot                                           0.0     0.0     0.0
# 01-01-00: The Novel of the Millennium                  0.0     0.0     0.0
# 10 Lb. Penalty                                         0.0     0.0     0.0
# 1001 Ways to Be Romantic                               0.0     0.0     0.0
# ...                                                    ...     ...     ...
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
# \Surely You're Joking, Mr. Feynman!\": Adventur...     0.0     0.0     0.0
# e                                                      0.0     0.0     0.0
# one hundred years of solitude                          0.0     0.0     0.0
# stardust                                               0.0     0.0     0.0
#
# User-ID                                             278137  278188  278418
# Book-Title
#  Q-Space (Star Trek The Next Generation, Book 47)      0.0     0.0     0.0
# 'Salem's Lot                                           0.0     0.0     0.0
# 01-01-00: The Novel of the Millennium                  0.0     0.0     0.0
# 10 Lb. Penalty                                         0.0     0.0     0.0
# 1001 Ways to Be Romantic                               0.0     0.0     0.0
# ...                                                    ...     ...     ...
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
# \Surely You're Joking, Mr. Feynman!\": Adventur...     0.0     0.0     0.0
# e                                                      0.0     0.0     0.0
# one hundred years of solitude                          0.0     0.0     0.0
# stardust                                               0.0     0.0     0.0
#
# [9934 rows x 1645 columns]

# %%
# these data are now similar, so we are going to take vectors of the books and check the similarity

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity_scores = cosine_similarity(pt)
similarity_scores[0]
# Out:
# array([1., 0., 0., ..., 0., 0., 0.], shape=(9934,))

# %%
def recommand(book_name):
    index = np.where(pt.index == book_name)[0][0]
    similar_items = sorted(
        list(enumerate(similarity_scores[index])),
        key=lambda x: x[1],
        reverse=True
    )[1:8]
    
    data = []
    for i in similar_items:
        item = []
        temp_df = books[books['Book-Title'] == pt.index[i[0]]]
        
        temp_df = temp_df.drop_duplicates('Book-Title')  # avoid repeating
        
        item.extend(list(temp_df['Book-Title'].values))
        item.extend(list(temp_df['Book-Author'].values))
        item.extend(list(temp_df['Image-URL-M'].values))  # <-- fixed here
        
        data.append(item)
    return data

# %%
np.where(pt.index == "1984")[0][0]
# Out:
# np.int64(11)

# %%
sorted(list(enumerate(similarity_scores[0])), key = lambda x:x[1], reverse = True)[1:8]
# Out:
# [(8465, np.float64(0.6154574548966636)),
#  (3641, np.float64(0.5008183311531246)),
#  (2503, np.float64(0.4923659639173309)),
#  (2867, np.float64(0.4923659639173309)),
#  (2823, np.float64(0.46368166406374195)),
#  (8447, np.float64(0.43654358232134327)),
#  (1044, np.float64(0.4351941398892445))]

# %%
recommand('1984')
# Out:
# [['Animal Farm',
#   'George Orwell',
#   'http://images.amazon.com/images/P/0451526341.01.MZZZZZZZ.jpg'],
#  ['Lying Awake',
#   'Mark Salzman',
#   'http://images.amazon.com/images/P/0375406328.01.MZZZZZZZ.jpg'],
#  ['S.',
#   'John Updike',
#   'http://images.amazon.com/images/P/0449216527.01.MZZZZZZZ.jpg'],
#  ['Far from the Madding Crowd',
#   'Thomas Hardy',
#   'http://images.amazon.com/images/P/0451528565.01.MZZZZZZZ.jpg'],
#  ['Waiting',
#   'Frank M. Robinson',
#   'http://images.amazon.com/images/P/0812541642.01.MZZZZZZZ.jpg'],
#  ['Written on the Body',
#   'Jeanette Winterson',
#   'http://images.amazon.com/images/P/0679744479.01.MZZZZZZZ.jpg'],
#  ['Brave New World',
#   'Aldous Huxley',
#   'http://images.amazon.com/images/P/0060809833.01.MZZZZZZZ.jpg']]

# %%
pt.index[56]
# Out:
# 'A Calculated Risk'

# %%
recommand('Message in a Bottle')
# Out:
# [['A Walk to Remember',
#   'Nicholas Sparks',
#   'http://images.amazon.com/images/P/0446608955.01.MZZZZZZZ.jpg'],
#  ['The Loop: A Novel',
#   'Nicholas Evans',
#   'http://images.amazon.com/images/P/038531700X.01.MZZZZZZZ.jpg'],
#  ['Evergreen',
#   'Belva Plain',
#   'http://images.amazon.com/images/P/0440132789.01.MZZZZZZZ.jpg'],
#  ['Nights in Rodanthe',
#   'Nicholas Sparks',
#   'http://images.amazon.com/images/P/0446531332.01.MZZZZZZZ.jpg'],
#  ['Wildest Heart',
#   'Rosemary Rogers',
#   'http://images.amazon.com/images/P/0380001373.01.MZZZZZZZ.jpg'],
#  ['My Sexiest Mistake (Blaze, 44)',
#   'Kristin Hardy',
#   'http://images.amazon.com/images/P/0373790481.01.MZZZZZZZ.jpg'],
#  ['Petals on the River',
#   'Kathleen E. Woodiwiss',
#   'http://images.amazon.com/images/P/038076654X.01.MZZZZZZZ.jpg']]

# %%
import pickle
pickle.dump(popularity_df, open('popular.pkl', 'wb'))

# %%
pickle.dump(books, open('books.pkl', 'wb'))
pickle.dump(similarity_scores, open('similarity_scores.pkl', 'wb'))
pickle.dump(pt, open('pt.pkl', 'wb'))
